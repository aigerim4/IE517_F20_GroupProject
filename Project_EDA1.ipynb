# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/aiger/Desktop/MSFE/IE517/Group_project/Data_sets/MLF_GP1_CreditScore.csv")

# %%
from sklearn.preprocessing import LabelEncoder

# %%
class_le=LabelEncoder()
y=class_le.fit_transform(df['Rating'].values)
y=y.reshape(-1,1)
y
df['Rating2']=y

# %%
df.head()
# Out:
#    Sales/Revenues  Gross Margin    EBITDA  EBITDA Margin  \
# 0       -0.005496      0.030763  0.018885       0.024515
# 1       -0.005496      0.030763  0.088716       0.094733
# 2       -0.007045      0.023159  0.088716       0.096440
# 3       -0.009396      0.028400  0.088716       0.099046
# 4       -0.009009      0.027714  0.088716       0.098611
#
#    Net Income Before Extras  Total Debt  Net Debt   LT Debt   ST Debt  \
# 0                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 1                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 2                  0.108590    0.039410  0.034268  0.009059  0.250371
# 3                  0.146137    0.030071  0.036938 -0.016964  0.356994
# 4                  0.123500    0.024224  0.034445 -0.034132  0.461894
#
#        Cash  ...  Total Liquidity  Current Liquidity  Current Liabilities  \
# 0 -0.133716  ...         0.392143          -0.184887             0.062781
# ...

# %%
Rating=df.Rating.unique()
print(Rating)
le=LabelEncoder()
stdsc=StandardScaler()
X=df.drop(['InvGrd','Rating'],axis=1).values
X=stdsc.fit_transform(X)
y_grade=df['InvGrd'].values
y_rating=le.fit_transform(df['Rating'].values)
y_rating
# Out:
# ['A1' 'A2' 'A3' 'Aa2' 'Aa3' 'Aaa' 'B1' 'B2' 'B3' 'Ba1' 'Ba2' 'Ba3' 'Baa1'
#  'Baa2' 'Baa3' 'Caa1']
# array([ 0,  0,  0, ..., 15, 15, 15])

# %%
Rating= df.Rating.unique()
Rating2=df.Rating2.unique()
paired=np.vstack((Rating, Rating2)).T
print(paired)
print(df['Rating2'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['Rating2'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# [['A1' 0]
#  ['A2' 1]
#  ['A3' 2]
#  ['Aa2' 3]
#  ['Aa3' 4]
#  ['Aaa' 5]
#  ['B1' 6]
#  ['B2' 7]
#  ['B3' 8]
#  ['Ba1' 9]
#  ['Ba2' 10]
#  ['Ba3' 11]
#  ['Baa1' 12]
#  ['Baa2' 13]
#  ['Baa3' 14]
#  ['Caa1' 15]]
# count    1700.000000
# mean        8.544118
# std         4.978570
# min         0.000000
# 25%         4.000000
# 50%        11.000000
# 75%        13.000000
# max        15.000000
# Name: Rating2, dtype: float64

# %%
import numpy as np
cols =['Sales/Revenues','Gross Margin','EBITDA','EBITDA Margin', 'Net Income Before Extras','Rating2']
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size': 15},
                yticklabels=cols,
                xticklabels=cols)
plt.show()

# %%
import numpy as np
cols =['Total Debt','Net Debt','LT Debt','ST Debt','Rating2']
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size': 15},
                yticklabels=cols,
                xticklabels=cols)
plt.show()

# %%
import numpy as np
cols =['Cash','Free Cash Flow','Total Debt/EBITDA','Net Debt/EBITDA','Rating2']
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size': 15},
                yticklabels=cols,
                xticklabels=cols)
plt.show()

# %%
import numpy as np
cols =['Total MV','Total Debt/MV','Net Debt/MV','CFO/Debt','CFO','Interest Coverage','Rating2']
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size': 15},
                yticklabels=cols,
                xticklabels=cols)
plt.show()

# %%
import numpy as np
cols =['Total Liquidity','Current Liquidity','Current Liabilities','EPS Before Extras','PE','ROA','ROE','Rating2']
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,
                cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size': 12},
                yticklabels=cols,
                xticklabels=cols)
plt.show()

# %%
#Histogram
import matplotlib.pyplot as plt 
plt.figure(figsize=(15, 5))
plt.xlabel('Credit Ratings')
plt.ylabel('Amounts')
plt.title('Moodys Histogram')
plt.xticks(fontsize=10, rotation =40)
_=plt.hist(df['Rating'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df.iloc[:,[0, 1, 2, 28]], height = 2.5)
plt.tight_layout()
plt.show()

# %%
df_corr = df.corr()['Rating2'][:-2] # -1 because the latest row is SalePrice
golden_features_list = df_corr[abs(df_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with Rating2:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 0 strongly correlated values with Rating2:
# Series([], Name: Rating2, dtype: float64)

# %%
import operator

individual_features_df = []
for i in range(0, len(df1.columns) - 2): # -1 because the last column is Rating2
    tmpDf = df1[[df1.columns[i], 'Rating2']]
    tmpDf = tmpDf[tmpDf[df1.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['Rating2'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
#          EBITDA: -0.047805406296976743
#         LT Debt: -0.03546513053249403
# Current Liabilities: -0.033191268107600855
#  Sales/Revenues: -0.03307635625801757
#             ROE: -0.019682544692332906
#   EBITDA Margin: -0.013842237272993047
#             CFO: -0.013647951995117702
#  Free Cash Flow: -0.008137876440091658
#             ROA: -0.00302134201191288
# Net Income Before Extras: -0.0024339737042315484
# EPS Before Extras: 0.0004598091333196788
#        CFO/Debt: 0.0007815230426020941
#              PE: 0.003645131014596827
#      Total Debt: 0.0037621731922666234
# Total Debt/EBITDA: 0.005027063166987285
#   Total Debt/MV: 0.005465531871251029
#        Net Debt: 0.015009939246999187
# Net Debt/EBITDA: 0.016653117806062677
#     Net Debt/MV: 0.019803575897970143
#         ST Debt: 0.028577179034722126
# Total Liquidity: 0.02969756725833042
#    Gross Margin: 0.0470311297155997
# Interest Coverage: 0.04948406178029652
#        Total MV: 0.05236876339943873
# ...

# %%
golden_features_list = [key for key, value in all_correlations if abs(value) >= 0.05]
print("There is {} correlated values with Rating2:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 3 correlated values with Rating2:
# ['Total MV', 'Cash', 'Current Liquidity']

# %%
df1.columns
# Out:
# Index(['Sales/Revenues', 'Gross Margin', 'EBITDA', 'EBITDA Margin',
#        'Net Income Before Extras', 'Total Debt', 'Net Debt', 'LT Debt',
#        'ST Debt', 'Cash', 'Free Cash Flow', 'Total Debt/EBITDA',
#        'Net Debt/EBITDA', 'Total MV', 'Total Debt/MV', 'Net Debt/MV',
#        'CFO/Debt', 'CFO', 'Interest Coverage', 'Total Liquidity',
#        'Current Liquidity', 'Current Liabilities', 'EPS Before Extras', 'PE',
#        'ROA', 'ROE', 'InvGrd', 'Rating2'],
#       dtype='object')

# %%
quantitative_features_list = ['Sales/Revenues', 'Gross Margin', 'EBITDA', 'EBITDA Margin',
       'Net Income Before Extras', 'Total Debt', 'Net Debt', 'LT Debt',
       'ST Debt', 'Cash', 'Free Cash Flow', 'Total Debt/EBITDA',
       'Net Debt/EBITDA', 'Total MV', 'Total Debt/MV', 'Net Debt/MV',
       'CFO/Debt', 'CFO', 'Interest Coverage', 'Total Liquidity',
       'Current Liquidity', 'Current Liabilities', 'EPS Before Extras', 'PE',
       'ROA', 'ROE', 'Rating2']
df_quantitative_values = df[quantitative_features_list]
df_quantitative_values.head()
# Out:
#    Sales/Revenues  Gross Margin    EBITDA  EBITDA Margin  \
# 0       -0.005496      0.030763  0.018885       0.024515
# 1       -0.005496      0.030763  0.088716       0.094733
# 2       -0.007045      0.023159  0.088716       0.096440
# 3       -0.009396      0.028400  0.088716       0.099046
# 4       -0.009009      0.027714  0.088716       0.098611
#
#    Net Income Before Extras  Total Debt  Net Debt   LT Debt   ST Debt  \
# 0                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 1                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 2                  0.108590    0.039410  0.034268  0.009059  0.250371
# 3                  0.146137    0.030071  0.036938 -0.016964  0.356994
# 4                  0.123500    0.024224  0.034445 -0.034132  0.461894
#
#        Cash  ...       CFO  Interest Coverage  Total Liquidity  \
# 0 -0.133716  ...  0.068526           0.136748         0.392143
# 1 -0.133716  ...  0.068526           0.214657         0.392143
# ...

# %%
features_to_analyse = [x for x in quantitative_features_list if x in golden_features_list]
features_to_analyse.append('Rating2')
features_to_analyse
# Out:
# ['Cash', 'Total MV', 'Current Liquidity', 'Rating2']

# %%
fig, ax = plt.subplots(round(len(features_to_analyse) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse) - 1:
        sns.regplot(x='Rating2',y=features_to_analyse[i], data=df[features_to_analyse], ax=ax)

# %%
corr = df.drop(['Rating', 'InvGrd', 'Rating2'], axis=1).corr() 
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
corr = df.drop(['Rating'], axis=1).corr() 
plt.figure(figsize=(25, 10))

sns.heatmap(corr[(corr >= 0.05) | (corr <= -0.05)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
corMat= df.drop(['Rating'], axis=1).corr()
plt.figure(figsize=(25, 15))
sns.heatmap(corMat,cbar=True,square=True, fmt='.2f',annot=True,annot_kws={'size': 12},cmap='viridis')
